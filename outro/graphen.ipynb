# %% [markdown]
# # Graphen und networkx
#
# Graphen lassen sich leicht mit dem Paket [NetworkX](https://networkx.org/documentation/stable/index.html) in Python handhaben.
#
# Um die Fähigkeiten zu demonstrieren, erzeugen wir einen Graphen, den [Petersen-Graphen](https://en.wikipedia.org/wiki/Petersen_graph), [färben](https://en.wikipedia.org/wiki/Graph_coloring) und zeichnen ihn. NetworkX bietet eine Reihe von Algorithmen und Funktionalitäten für Graphen.

# %%
import networkx as nx
import matplotlib.pyplot as plt
# erzeuge Petersengraphen
G = nx.petersen_graph()
# greedy Färbung der Ecken, so dass benachbarte Ecken unterschiedliche Farben erhalten
colouring=nx.greedy_color(G)
# wir machen uns die Farben ein wenig schöner
col_map={0:"tab:blue",1:"tab:orange",2:"tab:green",3:"tab:pink"}
col_list=[col_map[c] for c in colouring.values()]
# zeichne Graphen, so dass die Ecken in einem Kreis angeordnet werden
nx.draw_circular(G,node_color=col_list)
